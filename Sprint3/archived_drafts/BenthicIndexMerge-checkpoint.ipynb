# %%
import numpy as np
import pandas as pd
import glob as glob

# %%
path = r'J:\Brainstation\Capstone Git\Apollo_Beach_Model\data\PossibleDataSources'

# %%
csv_files=glob.glob('*.csv')

# %%
csv_files
# Out:
# ['BenthicBaseAreas.csv',
#  'BenthicBaseFieldSamples.csv',
#  'BenthicBaseFundingProject.csv',
#  'BenthicBaseHeader.csv',
#  'BenthicBasePrograms.csv',
#  'BenthicBaseProgramsStations.csv',
#  'BenthicBaseSegmentName.csv',
#  'BenthicBaseStations.csv',
#  'BenthicBaseTaxaCount.csv',
#  'BenthicBaseTaxaIdGroup.csv',
#  'BenthicBaseTaxaList.csv',
#  'BenthicBaseTaxaUnits.csv']

# %%
df_list

# %%
[var for var in dir() if isinstance(eval(var), pd.core.frame.DataFrame)].info()

# %%
_113
# Out:
#    TaxaID  StationID  Grab  TaxaListId  COUNT  Qualifier VOUCHER_NUM  \
# 0  175920     2484.0     2         988    1.0        NaN         NaN
# 1  152055    11321.0     1        1198    1.0        NaN         NaN
# 2  152056    11321.0     1        1224    1.0        NaN         NaN
#
#                                          ID_COMMENTS  LabIDNumber  EnteredBy  \
# 0  orig id= Crepidula sp., bumped up due to gener...          NaN        NaN
# 1                                     large specimen          NaN    10040.0
# 2                                     large specimen          NaN    10040.0
#
#        EnteredDate  TaxonomistID  IDDate  Units  qcd  TaxaListID  NODCCODE  \
# 0  10/16/2012 0:00           1.0     NaN      1    1         988  5.10E+11
# 1   9/27/2010 0:00         140.0     NaN      1    0        1198  5.51E+11
# 2   9/27/2010 0:00         140.0     NaN      1    0        1224  5.52E+11
#
#   Type                 NAME   REFERENCE_YEAR  \
# 0  Fam        Calyptraeidae    Lamarck, 1809
# 1  Spe       Anomia simplex  d'Orbigny, 1853
# 2  Spe  Cardites floridanus   (Conrad, 1838)
#
#                                         PreviousName DESCRIP_REFERENCE  \
# 0  Crepidula sp. Lamarck, 1799 (all occurrences d...               NaN
# 1                                                NaN               NaN
# 2  Carditamera floridana Conrad, 1838; Cardita fl...               NaN
#
#    TAXA_ID      Genus Kingdom    PHYLUM SUBPHYLUM       CLASS  \
# 0        2  Crepidula     NaN  Mollusca       NaN  Gastropoda
# 1        2     Anomia     NaN  Mollusca       NaN    Bivalvia
# 2        2   Cardites     NaN  Mollusca       NaN    Bivalvia
#
#           SubClass            ORDER SUBORDER InfraOrder      FAMILY SUBFAMILY  \
# 0  Caenogastropoda  Littorinimorpha      NaN        NaN         NaN       NaN
# 1    Pteriomorphia        Pectinida      NaN        NaN   Anomiidae       NaN
# 2      Heterodonta        Carditida      NaN        NaN  Carditidae       NaN
#
#   COLONIAL/PLANKTONIC? TaxaDescription DateAdded  GulfChecklist  \
# 0                  NaN             NaN       NaN            1.0
# 1                  NaN             NaN       NaN            1.0
# 2                  NaN             NaN       NaN            1.0
#
#    FMRIChecklist  Active                  TS  FeedingID  EcoGroupId  \
# 0            1.0     1.0  0x000000000008EDCC        NaN         3.0
# 1            1.0     1.0  0x000000000008EE80        NaN         1.0
# 2            1.0     1.0  0x000000000008EE9A        NaN         NaN
#
#    Epifaunal FeedingReference        Infraclass     Superfamily  \
# 0        NaN              NaN               NaN  Calyptraeoidea
# 1        NaN              NaN               NaN      Anomioidea
# 2        NaN              NaN  Archiheterodonta     Carditoidea
#
#       LastReviewed                                      ReviewSource
# 0  11/30/2023 0:00                                             WORMs
# 1  11/30/2023 0:00                                             WORMs
# 2  11/30/2023 0:00  WORMs; Genus change 12/2002; Genus change 4/2021

# %%
# Running into encoding issues
for file in csv_files:
    dfs[file]=pd.read_csv(file)

# %%
# Attempt to read csv with different encoding
bbAreas_df=pd.read_csv('BenthicBaseAreas.csv')
bbFieldSamples=pd.read_csv('BenthicBaseFieldSamples.csv')
bbFundingProject=pd.read_csv('BenthicBaseFundingProject.csv')
bbHeader=pd.read_csv('BenthicBaseHeader.csv', sep=",", encoding='cp1252')
bbPrograms=pd.read_csv('BenthicBasePrograms.csv')
bbProgramsSts=pd.read_csv('BenthicBaseProgramsStations.csv')
bbSegName=pd.read_csv('BenthicBaseSegmentName.csv')
bbStations=pd.read_csv('BenthicBaseStations.csv')
bbTaxaCt=pd.read_csv('BenthicBaseTaxaCount.csv',sep=",", encoding='cp1252')
bbTaxaID=pd.read_csv('BenthicBaseTaxaIDGroup.csv', sep=",", encoding='cp1252')
bbTaxaList=pd.read_csv('BenthicBaseTaxaList.csv', sep=",", encoding='cp1252')
bbTaxaUnits=pd.read_csv('BenthicBaseTaxaUnits.csv')
# Success

# %%
#bbTaxaCtMergeSample.drop(bbTaxaCtMergeSample.columns[15],axis=1,inplace=True)
bbTaxaCtMerge.head(2)
# Out:
#    TaxaID  StationID  Grab  TaxaListId  COUNT VOUCHER_NUM  \
# 0  175920     2484.0     2         988    1.0         NaN
# 1  152055    11321.0     1        1198    1.0         NaN
#
#                                          ID_COMMENTS  Units  qcd  TaxaListID  \
# 0  orig id= Crepidula sp., bumped up due to gener...      1    1         988
# 1                                     large specimen      1    0        1198
#
#    NODCCODE Type            NAME   REFERENCE_YEAR  \
# 0  5.10E+11  Fam   Calyptraeidae    Lamarck, 1809
# 1  5.51E+11  Spe  Anomia simplex  d'Orbigny, 1853
#
#                                         PreviousName DESCRIP_REFERENCE  \
# 0  Crepidula sp. Lamarck, 1799 (all occurrences d...               NaN
# 1                                                NaN               NaN
#
#    TAXA_ID      Genus Kingdom    PHYLUM SUBPHYLUM       CLASS  \
# 0        2  Crepidula     NaN  Mollusca       NaN  Gastropoda
# 1        2     Anomia     NaN  Mollusca       NaN    Bivalvia
#
#           SubClass            ORDER SUBORDER InfraOrder     FAMILY SUBFAMILY  \
# 0  Caenogastropoda  Littorinimorpha      NaN        NaN        NaN       NaN
# 1    Pteriomorphia        Pectinida      NaN        NaN  Anomiidae       NaN
#
#   COLONIAL/PLANKTONIC? TaxaDescription DateAdded  GulfChecklist  \
# 0                  NaN             NaN       NaN            1.0
# 1                  NaN             NaN       NaN            1.0
#
#    FMRIChecklist  Active                  TS  FeedingID  EcoGroupId  \
# 0            1.0     1.0  0x000000000008EDCC        NaN         3.0
# 1            1.0     1.0  0x000000000008EE80        NaN         1.0
#
#    Epifaunal FeedingReference Infraclass     Superfamily     LastReviewed  \
# 0        NaN              NaN        NaN  Calyptraeoidea  11/30/2023 0:00
# 1        NaN              NaN        NaN      Anomioidea  11/30/2023 0:00
#
#   ReviewSource
# 0        WORMs
# 1        WORMs

# %%
# Random columns introduced in merge? No data. Dropping
#bbTaxaCt.drop(columns=['Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],inplace=True)

# %%
bbTaxaCtMerge.drop(bbTaxaCtMerge.columns[13:14], axis=1, inplace=True)

# %%
bbTaxaCtMerge.Type.value_counts()
# Out:
# Type
# Spe    113066
# Gen     16887
# Fam      9778
# Cls      3165
# Sbf      2298
# Ord       946
# Phy       549
# Ifo       432
# Sbc       223
# Spf       151
# Sbo        62
# Ifc        22
# Name: count, dtype: int64

# %%
bbTaxaCtMerge.columns[16]
bbTaxaCtMerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153307 entries, 0 to 153306
# Data columns (total 42 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   TaxaID                153307 non-null  int64
#  1   StationID             153306 non-null  float64
#  2   Grab                  153307 non-null  int64
#  3   TaxaListId            153307 non-null  int64
#  4   COUNT                 153305 non-null  float64
#  5   VOUCHER_NUM           4486 non-null    object
#  6   ID_COMMENTS           63222 non-null   object
#  7   Units                 153307 non-null  int64
#  8   qcd                   153307 non-null  int64
#  9   TaxaListID            153307 non-null  int64
#  10  NODCCODE              153201 non-null  object
#  11  Type                  147579 non-null  object
#  12  NAME                  153307 non-null  object
#  13  PreviousName          66370 non-null   object
#  14  DESCRIP_REFERENCE     20469 non-null   object
#  15  TAXA_ID               153307 non-null  int64
#  16  Genus                 129714 non-null  object
#  17  Kingdom               13485 non-null   object
#  18  PHYLUM                147579 non-null  object
#  19  SUBPHYLUM             37850 non-null   object
#  20  CLASS                 144561 non-null  object
#  21  SubClass              131832 non-null  object
#  22  ORDER                 119056 non-null  object
#  23  SUBORDER              71989 non-null   object
#  24  InfraOrder            22494 non-null   object
#  25  FAMILY                141085 non-null  object
#  26  SUBFAMILY             40696 non-null   object
#  27  COLONIAL/PLANKTONIC?  2539 non-null    object
#  28  TaxaDescription       72516 non-null   object
#  29  DateAdded             37023 non-null   object
#  30  GulfChecklist         135392 non-null  float64
#  31  FMRIChecklist         116998 non-null  float64
#  32  Active                153307 non-null  float64
#  33  TS                    153307 non-null  object
#  34  FeedingID             35087 non-null   float64
#  35  EcoGroupId            111538 non-null  float64
#  36  Epifaunal             1 non-null       float64
#  37  FeedingReference      35087 non-null   object
#  38  Infraclass            53856 non-null   object
#  39  Superfamily           58968 non-null   object
#  40  LastReviewed          146468 non-null  object
#  41  ReviewSource          141927 non-null  object
# dtypes: float64(8), int64(7), object(27)
# memory usage: 49.1+ MB

# %%
bbTaxaCtMerge
# Out:
#         TaxaID  StationID  Grab  TaxaListId  COUNT  Qualifier VOUCHER_NUM  \
# 0       175920     2484.0     2         988    1.0        NaN         NaN
# 1       152055    11321.0     1        1198    1.0        NaN         NaN
# 2       152056    11321.0     1        1224    1.0        NaN         NaN
# 3       233277      584.0     1         624    1.0        NaN         NaN
# 4       152057    11321.0     1        1306    3.0        NaN         NaN
# ...        ...        ...   ...         ...    ...        ...         ...
# 153302  245461     2693.0     1         102    1.0        NaN         NaN
# 153303  245511     2695.0     1         307    3.0        NaN         NaN
# 153304  245512     2696.0     1         531    1.0        NaN         NaN
# 153305  245514     2701.0     1         778    1.0        NaN         NaN
# 153306  245515     2702.0     1         613    1.0        NaN         NaN
#
#                                               ID_COMMENTS  LabIDNumber  \
# 0       orig id= Crepidula sp., bumped up due to gener...          NaN
# 1                                          large specimen          NaN
# 2                                          large specimen          NaN
# 3       orig id=Cirratulidae, reid SM 4/2019; anterior...          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 153302  orig id=Kirkegaardia sp, reid SM 11/2020;Small...          NaN
# 153303  orig id= S. sp. A of Wolf, 1984; anterior elyt...          NaN
# 153304          orig id=S. cf. rudolphi, reid SM 11/2020;          NaN
# 153305      additional specimen in vial, added SM 11/2020          NaN
# 153306  orig id=Monticellina dorsobranchialis, reid SM...          NaN
#
#         EnteredBy      EnteredDate  TaxonomistID  IDDate  Units  qcd  \
# 0             NaN  10/16/2012 0:00           1.0     NaN      1    1
# 1         10040.0   9/27/2010 0:00         140.0     NaN      1    0
# 2         10040.0   9/27/2010 0:00         140.0     NaN      1    0
# 3           116.0   4/23/2019 0:00         116.0     NaN      1    1
# 4         10040.0   9/27/2010 0:00         140.0     NaN      1    0
# ...           ...              ...           ...     ...    ...  ...
# 153302      116.0   11/5/2020 0:00         116.0     NaN      1    1
# 153303      116.0   11/9/2020 0:00         116.0     NaN      1    1
# 153304      116.0   11/9/2020 0:00         116.0     NaN      1    1
# 153305      116.0   11/9/2020 0:00         116.0     NaN      1    1
# 153306      116.0   11/9/2020 0:00         116.0     NaN      1    1
#
#         TaxaListID  NODCCODE Type                       NAME  \
# 0              988  5.10E+11  Fam              Calyptraeidae
# 1             1198  5.51E+11  Spe             Anomia simplex
# 2             1224  5.52E+11  Spe        Cardites floridanus
# 3              624  5.00E+11  Gen             Chaetozone sp.
# 4             1306  5.52E+11  Spe             Chione elevata
# ...            ...       ...  ...                        ...
# 153302         102  5.00E+11  Spe  Caulleriella sp. D of EPC
# 153303         307  5.00E+11  Spe         Sthenelais cf. boa
# 153304         531  5.00E+11  Spe       Pettiboneia duofurca
# 153305         778  5.00E+11  Gen            Polygordius sp.
# 153306         613  5.00E+11  Fam               CIRRATULIDAE
#
#           REFERENCE_YEAR                                       PreviousName  \
# 0          Lamarck, 1809  Crepidula sp. Lamarck, 1799 (all occurrences d...
# 1        d'Orbigny, 1853                                                NaN
# 2         (Conrad, 1838)  Carditamera floridana Conrad, 1838; Cardita fl...
# 3         Malmgren, 1867                                                NaN
# 4            (Say, 1822)               Chione cancellata changed on 12/5/02
# ...                  ...                                                ...
# 153302               NaN     Caulleriella cf. alata (all count occurrences)
# 153303  (Johnston, 1839)                                                NaN
# 153304        Wolf, 1987                    Pettiboneia sp. A of Wolf, 1984
# 153305   Schneider, 1868                                                NaN
# 153306    Ryckholt, 1851                                                NaN
#
#                                         DESCRIP_REFERENCE  TAXA_ID  \
# 0                                                     NaN        2
# 1                                                     NaN        2
# 2                                                     NaN        2
# 3                                                     NaN        1
# 4                                                     NaN        2
# ...                                                   ...      ...
# 153302                             Perkins correspondence        1
# 153303  Pettibone, 1963 Marine Polychaete Worms of the...        1
# 153304                                                NaN        1
# 153305                                                NaN        1
# 153306                                                NaN        1
#
#                Genus Kingdom    PHYLUM SUBPHYLUM       CLASS  \
# 0          Crepidula     NaN  Mollusca       NaN  Gastropoda
# 1             Anomia     NaN  Mollusca       NaN    Bivalvia
# 2           Cardites     NaN  Mollusca       NaN    Bivalvia
# 3         Chaetozone     NaN  Annelida       NaN  Polychaeta
# 4             Chione     NaN  Mollusca       NaN    Bivalvia
# ...              ...     ...       ...       ...         ...
# 153302  Caulleriella     NaN  Annelida       NaN  Polychaeta
# 153303    Sthenelais     NaN  Annelida       NaN  Polychaeta
# 153304   Pettiboneia     NaN  Annelida       NaN  Polychaeta
# 153305   Polygordius     NaN  Annelida       NaN  Polychaeta
# 153306           NaN     NaN  Annelida       NaN  Polychaeta
#
#                          SubClass            ORDER         SUBORDER  \
# 0                 Caenogastropoda  Littorinimorpha              NaN
# 1                   Pteriomorphia        Pectinida              NaN
# 2                     Heterodonta        Carditida              NaN
# 3                      Sedentaria      Terebellida  Cirratuliformia
# 4                     Heterodonta         Venerida              NaN
# ...                           ...              ...              ...
# 153302                 Sedentaria      Terebellida  Cirratuliformia
# 153303                   Errantia     Phyllodocida  Aphroditiformia
# 153304                   Errantia         Eunicida              NaN
# 153305  Polychaeta incertae sedis              NaN              NaN
# 153306                 Sedentaria      Terebellida  Cirratuliformia
#
#        InfraOrder         FAMILY SUBFAMILY COLONIAL/PLANKTONIC?  \
# 0             NaN            NaN       NaN                  NaN
# 1             NaN      Anomiidae       NaN                  NaN
# 2             NaN     Carditidae       NaN                  NaN
# 3             NaN   Cirratulidae       NaN                  NaN
# 4             NaN      Veneridae       NaN                  NaN
# ...           ...            ...       ...                  ...
# 153302        NaN   Cirratulidae       NaN                  NaN
# 153303        NaN   Sigalionidae       NaN                  NaN
# 153304        NaN   Dorvilleidae       NaN                  NaN
# 153305        NaN  Polygordiidae       NaN                  NaN
# 153306        NaN   Cirratulidae       NaN                  NaN
#
#                                           TaxaDescription DateAdded  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3                                                     NaN       NaN
# 4                                 on FMRI as C.cancellata       NaN
# ...                                                   ...       ...
# 153302  Perkins designation: palps, large eyes, hooks ...       NaN
# 153303  US reported species of S.leidyi and S.picta ha...       NaN
# 153304  Dorsal cirri with notoacicula; dorsal cirri pr...       NaN
# 153305                                                NaN       NaN
# 153306                                                NaN       NaN
#
#         GulfChecklist  FMRIChecklist  Active                  TS  FeedingID  \
# 0                 1.0            1.0     1.0  0x000000000008EDCC        NaN
# 1                 1.0            1.0     1.0  0x000000000008EE80        NaN
# 2                 1.0            1.0     1.0  0x000000000008EE9A        NaN
# 3                 1.0            1.0     1.0  0x000000000008EBBA        2.0
# 4                 1.0            1.0     1.0  0x000000000008EEE9        NaN
# ...               ...            ...     ...                 ...        ...
# 153302            NaN            NaN     1.0  0x000000000008EAE4        2.0
# 153303            1.0            1.0     1.0  0x000000000008EAF6        1.0
# 153304            1.0            1.0     1.0  0x000000000008EB80        1.0
# 153305            0.0            1.0     1.0  0x000000000008EC08        NaN
# 153306            1.0            1.0     1.0  0x000000000008EBB5        2.0
#
#         EcoGroupId  Epifaunal  \
# 0              3.0        NaN
# 1              1.0        NaN
# 2              NaN        NaN
# 3              2.0        NaN
# 4              2.0        NaN
# ...            ...        ...
# 153302         NaN        NaN
# 153303         2.0        NaN
# 153304         2.0        NaN
# 153305         1.0        NaN
# 153306         3.0        NaN
#
#                                          FeedingReference        Infraclass  \
# 0                                                     NaN               NaN
# 1                                                     NaN               NaN
# 2                                                     NaN  Archiheterodonta
# 3       Beesley, P.L., Ross, G.J.B. & Glasby, C.J.  (e...     Canalipalpata
# 4                                                     NaN     Euheterodonta
# ...                                                   ...               ...
# 153302  Beesley, P.L., Ross, G.J.B. & Glasby, C.J.  (e...     Canalipalpata
# 153303  Beesley, P.L., Ross, G.J.B. & Glasby, C.J.  (e...               NaN
# 153304  Beesley, P.L., Ross, G.J.B. & Glasby, C.J.  (e...               NaN
# 153305                                                NaN               NaN
# 153306  Beesley, P.L., Ross, G.J.B. & Glasby, C.J.  (e...     Canalipalpata
#
#            Superfamily     LastReviewed  \
# 0       Calyptraeoidea  11/30/2023 0:00
# 1           Anomioidea  11/30/2023 0:00
# 2          Carditoidea  11/30/2023 0:00
# 3                  NaN  11/28/2023 0:00
# 4           Veneroidea  11/30/2023 0:00
# ...                ...              ...
# 153302             NaN  11/28/2023 0:00
# 153303             NaN  11/28/2023 0:00
# 153304             NaN  11/28/2023 0:00
# 153305             NaN  11/28/2023 0:00
# 153306             NaN  11/28/2023 0:00
#
#                                              ReviewSource
# 0                                                   WORMs
# 1                                                   WORMs
# 2        WORMs; Genus change 12/2002; Genus change 4/2021
# 3                                                   WORMs
# 4                                                   WORMs
# ...                                                   ...
# 153302  combined C.cf.alata based on voucher and selec...
# 153303                                              WORMs
# 153304  Wolf, Paul S. 1987. Two new species of Pettibo...
# 153305                                              WORMs
# 153306                                              WORMs
#
# [153307 rows x 49 columns]

# %%
bbTaxaCtMerge=bbTaxaCt.merge(bbTaxaList, left_on='TaxaListId',right_on='TaxaListID')

# %%
# Random columns introduced in merge? No data. Dropping
# bbTaxaCtMerge.drop(columns=['Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],inplace=True)

# %%
bbTaxaCtMerge.head(3)
# Out:
#    TaxaID  StationID  Grab  TaxaListId  COUNT  Qualifier VOUCHER_NUM  \
# 0  175920     2484.0     2         988    1.0        NaN         NaN
# 1  152055    11321.0     1        1198    1.0        NaN         NaN
# 2  152056    11321.0     1        1224    1.0        NaN         NaN
#
#                                          ID_COMMENTS  LabIDNumber  EnteredBy  \
# 0  orig id= Crepidula sp., bumped up due to gener...          NaN        NaN
# 1                                     large specimen          NaN    10040.0
# 2                                     large specimen          NaN    10040.0
#
#        EnteredDate  TaxonomistID  IDDate  Units  qcd  TaxaListID  NODCCODE  \
# 0  10/16/2012 0:00           1.0     NaN      1    1         988  5.10E+11
# 1   9/27/2010 0:00         140.0     NaN      1    0        1198  5.51E+11
# 2   9/27/2010 0:00         140.0     NaN      1    0        1224  5.52E+11
#
#   Type                 NAME   REFERENCE_YEAR  \
# 0  Fam        Calyptraeidae    Lamarck, 1809
# 1  Spe       Anomia simplex  d'Orbigny, 1853
# 2  Spe  Cardites floridanus   (Conrad, 1838)
#
#                                         PreviousName DESCRIP_REFERENCE  \
# 0  Crepidula sp. Lamarck, 1799 (all occurrences d...               NaN
# 1                                                NaN               NaN
# 2  Carditamera floridana Conrad, 1838; Cardita fl...               NaN
#
#    TAXA_ID      Genus Kingdom    PHYLUM SUBPHYLUM       CLASS  \
# 0        2  Crepidula     NaN  Mollusca       NaN  Gastropoda
# 1        2     Anomia     NaN  Mollusca       NaN    Bivalvia
# 2        2   Cardites     NaN  Mollusca       NaN    Bivalvia
#
#           SubClass            ORDER SUBORDER InfraOrder      FAMILY SUBFAMILY  \
# 0  Caenogastropoda  Littorinimorpha      NaN        NaN         NaN       NaN
# 1    Pteriomorphia        Pectinida      NaN        NaN   Anomiidae       NaN
# 2      Heterodonta        Carditida      NaN        NaN  Carditidae       NaN
#
#   COLONIAL/PLANKTONIC? TaxaDescription DateAdded  GulfChecklist  \
# 0                  NaN             NaN       NaN            1.0
# 1                  NaN             NaN       NaN            1.0
# 2                  NaN             NaN       NaN            1.0
#
#    FMRIChecklist  Active                  TS  FeedingID  EcoGroupId  \
# 0            1.0     1.0  0x000000000008EDCC        NaN         3.0
# 1            1.0     1.0  0x000000000008EE80        NaN         1.0
# 2            1.0     1.0  0x000000000008EE9A        NaN         NaN
#
#    Epifaunal FeedingReference        Infraclass     Superfamily  \
# 0        NaN              NaN               NaN  Calyptraeoidea
# 1        NaN              NaN               NaN      Anomioidea
# 2        NaN              NaN  Archiheterodonta     Carditoidea
#
#       LastReviewed                                      ReviewSource
# 0  11/30/2023 0:00                                             WORMs
# 1  11/30/2023 0:00                                             WORMs
# 2  11/30/2023 0:00  WORMs; Genus change 12/2002; Genus change 4/2021

# %%
bbTaxaCtMerge.VOUCHER_NUM.value_counts()
# Out:
# VOUCHER_NUM
# Ann98075    2
# Cru14003    2
# Ann97117    2
# Ann09042    2
# Ann09047    2
#            ..
# Mol07014    1
# Mis07009    1
# Ann07023    1
# Ann07022    1
# Cru95005    1
# Name: count, Length: 4469, dtype: int64
